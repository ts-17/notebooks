# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import itertools
import warnings
from statsmodels.tsa.statespace.sarimax import SARIMAX

warnings.filterwarnings("ignore")

def generate_synthetic_data(n_periods=240):
    # dates don't matter here since it's synthetic data
    dates = pd.date_range(start='2000-01-01', periods=n_periods, freq='M')

    t = np.arange(n_periods)
    # a complex moving trend
    trend = 0.05 * t + 0.0003 * t**2 + 3 * np.sin(2 * np.pi * t / 120)

    # add a seasonal trend
    seasonality = 2 * np.sin(2 * np.pi * t / 12)

    # increasing std dev over time (more noise)
    noise_scale = 0.5 + np.random.uniform(0.002, 0.007) * t
    noise = np.random.normal(loc=0, scale=noise_scale)

    # add constant (10) for baseline
    data = 10 + trend + seasonality + noise

    return pd.Series(data, index=dates)

def parameter_sweep(train, seasonal_period=12):
    # p, d, q ranges for non-seasonal and seasonal parameter sweeps
    p = d = q = range(0, 3)
    pdq = list(itertools.product(p, d, q))
    seasonal_pdq = [(x[0], x[1], x[2], seasonal_period) for x in pdq]

    best_aic = np.inf
    best_order = None
    best_seasonal = None
    best_model = None

    print("Starting parameter sweep over SARIMA parameters...")
    for order in pdq:
        for seasonal_order in seasonal_pdq:
            try:
                model = SARIMAX(train,
                                order=order,
                                seasonal_order=seasonal_order,
                                enforce_stationarity=False,
                                enforce_invertibility=False)
                results = model.fit(disp=False)
                if results.aic < best_aic:
                    best_aic = results.aic
                    best_order = order
                    best_seasonal = seasonal_order
                    best_model = results
                print(f"Tested order: {order}, seasonal_order: {seasonal_order}, AIC: {results.aic:.2f}")
            except Exception as e:
                continue

    print("\nBest model found:")
    print(f"Order: {best_order}, Seasonal Order: {best_seasonal}, AIC: {best_aic:.2f}\n")
    return best_order, best_seasonal, best_model

def plot_forecasts(train, test, forecast, conf_int):
    plt.figure(figsize=(12, 6))

    plt.plot(train.index, train, label='Training Data')
    plt.plot(test.index, test, label='Test Data', color='blue')
    plt.plot(forecast.index, forecast, label='Forecast', color='red')

    plt.fill_between(conf_int.index,
                     conf_int.iloc[:, 0],
                     conf_int.iloc[:, 1],
                     color='pink', alpha=0.3, label='95% CI')

    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.title('SARIMA Model Forecasts')
    plt.legend()
    plt.tight_layout()
    plt.show()

def main():
    series = generate_synthetic_data(n_periods=240)

    # using last 40 observations as test set
    train, test = series.iloc[:-40], series.iloc[-40:]

    # param sweep for best AIC
    best_order, best_seasonal, best_model = parameter_sweep(train, seasonal_period=12)

    # one step ahead forecasts
    pred = best_model.get_prediction(start=test.index[0], end=test.index[-1], dynamic=False)
    pred_mean = pred.predicted_mean
    pred_conf_int = pred.conf_int(alpha=0.05)

    plot_forecasts(train, test, pred_mean, pred_conf_int)

if __name__ == '__main__':
    main()
# Out:
# Starting parameter sweep over SARIMA parameters...
# Tested order: (0, 0, 0), seasonal_order: (0, 0, 0, 12), AIC: 1771.58
# Tested order: (0, 0, 0), seasonal_order: (0, 0, 1, 12), AIC: 1464.08
# Tested order: (0, 0, 0), seasonal_order: (0, 0, 2, 12), AIC: 1222.83
# Tested order: (0, 0, 0), seasonal_order: (0, 1, 0, 12), AIC: 797.04
# Tested order: (0, 0, 0), seasonal_order: (0, 1, 1, 12), AIC: 705.46
# Tested order: (0, 0, 0), seasonal_order: (0, 1, 2, 12), AIC: 634.91
# Tested order: (0, 0, 0), seasonal_order: (0, 2, 0, 12), AIC: 729.82
# Tested order: (0, 0, 0), seasonal_order: (0, 2, 1, 12), AIC: 661.49
# Tested order: (0, 0, 0), seasonal_order: (0, 2, 2, 12), AIC: 607.04
# Tested order: (0, 0, 0), seasonal_order: (1, 0, 0, 12), AIC: 740.35
# Tested order: (0, 0, 0), seasonal_order: (1, 0, 1, 12), AIC: 724.30
# Tested order: (0, 0, 0), seasonal_order: (1, 0, 2, 12), AIC: 659.53
# Tested order: (0, 0, 0), seasonal_order: (1, 1, 0, 12), AIC: 684.60
# Tested order: (0, 0, 0), seasonal_order: (1, 1, 1, 12), AIC: 680.39
# Tested order: (0, 0, 0), seasonal_order: (1, 1, 2, 12), AIC: 625.37
# Tested order: (0, 0, 0), seasonal_order: (1, 2, 0, 12), AIC: 660.63
# Tested order: (0, 0, 0), seasonal_order: (1, 2, 1, 12), AIC: 661.60
# Tested order: (0, 0, 0), seasonal_order: (1, 2, 2, 12), AIC: 611.84
# Tested order: (0, 0, 0), seasonal_order: (2, 0, 0, 12), AIC: 671.80
# Tested order: (0, 0, 0), seasonal_order: (2, 0, 1, 12), AIC: 719.80
# Tested order: (0, 0, 0), seasonal_order: (2, 0, 2, 12), AIC: 674.60
# Tested order: (0, 0, 0), seasonal_order: (2, 1, 0, 12), AIC: 636.91
# Tested order: (0, 0, 0), seasonal_order: (2, 1, 1, 12), AIC: 637.15
# Tested order: (0, 0, 0), seasonal_order: (2, 1, 2, 12), AIC: 627.35
# Tested order: (0, 0, 0), seasonal_order: (2, 2, 0, 12), AIC: 614.02
# Tested order: (0, 0, 0), seasonal_order: (2, 2, 1, 12), AIC: 614.38
# Tested order: (0, 0, 0), seasonal_order: (2, 2, 2, 12), AIC: 613.15
# Tested order: (0, 0, 1), seasonal_order: (0, 0, 0, 12), AIC: 1514.63
# Tested order: (0, 0, 1), seasonal_order: (0, 0, 1, 12), AIC: 1236.77
# Tested order: (0, 0, 1), seasonal_order: (0, 0, 2, 12), AIC: 1066.10
# Tested order: (0, 0, 1), seasonal_order: (0, 1, 0, 12), AIC: 711.34
# Tested order: (0, 0, 1), seasonal_order: (0, 1, 1, 12), AIC: 655.30
# Tested order: (0, 0, 1), seasonal_order: (0, 1, 2, 12), AIC: 599.38
# Tested order: (0, 0, 1), seasonal_order: (0, 2, 0, 12), AIC: 716.73
# Tested order: (0, 0, 1), seasonal_order: (0, 2, 1, 12), AIC: 614.63
# Tested order: (0, 0, 1), seasonal_order: (0, 2, 2, 12), AIC: 570.86
# Tested order: (0, 0, 1), seasonal_order: (1, 0, 0, 12), AIC: 682.18
# Tested order: (0, 0, 1), seasonal_order: (1, 0, 1, 12), AIC: 676.85
# Tested order: (0, 0, 1), seasonal_order: (1, 0, 2, 12), AIC: 623.52
# Tested order: (0, 0, 1), seasonal_order: (1, 1, 0, 12), AIC: 657.26
# Tested order: (0, 0, 1), seasonal_order: (1, 1, 1, 12), AIC: 647.44
# Tested order: (0, 0, 1), seasonal_order: (1, 1, 2, 12), AIC: 594.97
# Tested order: (0, 0, 1), seasonal_order: (1, 2, 0, 12), AIC: 632.71
# Tested order: (0, 0, 1), seasonal_order: (1, 2, 1, 12), AIC: 625.26
# Tested order: (0, 0, 1), seasonal_order: (1, 2, 2, 12), AIC: 575.06
# Tested order: (0, 0, 1), seasonal_order: (2, 0, 0, 12), AIC: 636.83
# Tested order: (0, 0, 1), seasonal_order: (2, 0, 1, 12), AIC: 638.83
# Tested order: (0, 0, 1), seasonal_order: (2, 0, 2, 12), AIC: 625.44
# Tested order: (0, 0, 1), seasonal_order: (2, 1, 0, 12), AIC: 604.27
# Tested order: (0, 0, 1), seasonal_order: (2, 1, 1, 12), AIC: 606.20
# Tested order: (0, 0, 1), seasonal_order: (2, 1, 2, 12), AIC: 597.13
# Tested order: (0, 0, 1), seasonal_order: (2, 2, 0, 12), AIC: 590.29
# Tested order: (0, 0, 1), seasonal_order: (2, 2, 1, 12), AIC: 590.02
# Tested order: (0, 0, 1), seasonal_order: (2, 2, 2, 12), AIC: 580.47
# Tested order: (0, 0, 2), seasonal_order: (0, 0, 0, 12), AIC: 1304.57
# Tested order: (0, 0, 2), seasonal_order: (0, 0, 1, 12), AIC: 1097.58
# Tested order: (0, 0, 2), seasonal_order: (0, 0, 2, 12), AIC: 960.91
# Tested order: (0, 0, 2), seasonal_order: (0, 1, 0, 12), AIC: 668.36
# Tested order: (0, 0, 2), seasonal_order: (0, 1, 1, 12), AIC: 621.23
# Tested order: (0, 0, 2), seasonal_order: (0, 1, 2, 12), AIC: 573.16
# Tested order: (0, 0, 2), seasonal_order: (0, 2, 0, 12), AIC: 711.21
# Tested order: (0, 0, 2), seasonal_order: (0, 2, 1, 12), AIC: 582.16
# Tested order: (0, 0, 2), seasonal_order: (0, 2, 2, 12), AIC: 541.27
# Tested order: (0, 0, 2), seasonal_order: (1, 0, 0, 12), AIC: 656.25
# Tested order: (0, 0, 2), seasonal_order: (1, 0, 1, 12), AIC: 678.58
# Tested order: (0, 0, 2), seasonal_order: (1, 0, 2, 12), AIC: 599.00
# Tested order: (0, 0, 2), seasonal_order: (1, 1, 0, 12), AIC: 632.14
# Tested order: (0, 0, 2), seasonal_order: (1, 1, 1, 12), AIC: 621.98
# Tested order: (0, 0, 2), seasonal_order: (1, 1, 2, 12), AIC: 571.40
# Tested order: (0, 0, 2), seasonal_order: (1, 2, 0, 12), AIC: 618.11
# Tested order: (0, 0, 2), seasonal_order: (1, 2, 1, 12), AIC: 584.10
# Tested order: (0, 0, 2), seasonal_order: (1, 2, 2, 12), AIC: 545.08
# Tested order: (0, 0, 2), seasonal_order: (2, 0, 0, 12), AIC: 608.88
# Tested order: (0, 0, 2), seasonal_order: (2, 0, 1, 12), AIC: 612.94
# Tested order: (0, 0, 2), seasonal_order: (2, 0, 2, 12), AIC: 600.31
# Tested order: (0, 0, 2), seasonal_order: (2, 1, 0, 12), AIC: 582.96
# Tested order: (0, 0, 2), seasonal_order: (2, 1, 1, 12), AIC: 584.34
# Tested order: (0, 0, 2), seasonal_order: (2, 1, 2, 12), AIC: 572.83
# Tested order: (0, 0, 2), seasonal_order: (2, 2, 0, 12), AIC: 568.93
# Tested order: (0, 0, 2), seasonal_order: (2, 2, 1, 12), AIC: 552.86
# Tested order: (0, 0, 2), seasonal_order: (2, 2, 2, 12), AIC: 547.08
# Tested order: (0, 1, 0), seasonal_order: (0, 0, 0, 12), AIC: 657.66
# Tested order: (0, 1, 0), seasonal_order: (0, 0, 1, 12), AIC: 598.28
# Tested order: (0, 1, 0), seasonal_order: (0, 0, 2, 12), AIC: 552.56
# Tested order: (0, 1, 0), seasonal_order: (0, 1, 0, 12), AIC: 645.88
# Tested order: (0, 1, 0), seasonal_order: (0, 1, 1, 12), AIC: 533.24
# Tested order: (0, 1, 0), seasonal_order: (0, 1, 2, 12), AIC: 509.30
# Tested order: (0, 1, 0), seasonal_order: (0, 2, 0, 12), AIC: 788.65
# Tested order: (0, 1, 0), seasonal_order: (0, 2, 1, 12), AIC: 591.37
# Tested order: (0, 1, 0), seasonal_order: (0, 2, 2, 12), AIC: 501.42
# Tested order: (0, 1, 0), seasonal_order: (1, 0, 0, 12), AIC: 589.55
# Tested order: (0, 1, 0), seasonal_order: (1, 0, 1, 12), AIC: 570.60
# Tested order: (0, 1, 0), seasonal_order: (1, 0, 2, 12), AIC: 542.04
# Tested order: (0, 1, 0), seasonal_order: (1, 1, 0, 12), AIC: 562.46
# Tested order: (0, 1, 0), seasonal_order: (1, 1, 1, 12), AIC: 547.00
# Tested order: (0, 1, 0), seasonal_order: (1, 1, 2, 12), AIC: 510.10
# Tested order: (0, 1, 0), seasonal_order: (1, 2, 0, 12), AIC: 644.22
# Tested order: (0, 1, 0), seasonal_order: (1, 2, 1, 12), AIC: 564.43
# Tested order: (0, 1, 0), seasonal_order: (1, 2, 2, 12), AIC: 523.49
# Tested order: (0, 1, 0), seasonal_order: (2, 0, 0, 12), AIC: 540.86
# Tested order: (0, 1, 0), seasonal_order: (2, 0, 1, 12), AIC: 541.98
# Tested order: (0, 1, 0), seasonal_order: (2, 0, 2, 12), AIC: 535.70
# Tested order: (0, 1, 0), seasonal_order: (2, 1, 0, 12), AIC: 523.26
# Tested order: (0, 1, 0), seasonal_order: (2, 1, 1, 12), AIC: 514.47
# Tested order: (0, 1, 0), seasonal_order: (2, 1, 2, 12), AIC: 512.22
# Tested order: (0, 1, 0), seasonal_order: (2, 2, 0, 12), AIC: 560.29
# Tested order: (0, 1, 0), seasonal_order: (2, 2, 1, 12), AIC: 525.39
# Tested order: (0, 1, 0), seasonal_order: (2, 2, 2, 12), AIC: 520.03
# Tested order: (0, 1, 1), seasonal_order: (0, 0, 0, 12), AIC: 657.31
# Tested order: (0, 1, 1), seasonal_order: (0, 0, 1, 12), AIC: 593.13
# Tested order: (0, 1, 1), seasonal_order: (0, 0, 2, 12), AIC: 542.82
# Tested order: (0, 1, 1), seasonal_order: (0, 1, 0, 12), AIC: 575.90
# Tested order: (0, 1, 1), seasonal_order: (0, 1, 1, 12), AIC: 489.00
# Tested order: (0, 1, 1), seasonal_order: (0, 1, 2, 12), AIC: 464.49
# Tested order: (0, 1, 1), seasonal_order: (0, 2, 0, 12), AIC: 708.97
# Tested order: (0, 1, 1), seasonal_order: (0, 2, 1, 12), AIC: 535.70
# Tested order: (0, 1, 1), seasonal_order: (0, 2, 2, 12), AIC: 467.01
# Tested order: (0, 1, 1), seasonal_order: (1, 0, 0, 12), AIC: 561.16
# Tested order: (0, 1, 1), seasonal_order: (1, 0, 1, 12), AIC: 522.99
# Tested order: (0, 1, 1), seasonal_order: (1, 0, 2, 12), AIC: 496.63
# Tested order: (0, 1, 1), seasonal_order: (1, 1, 0, 12), AIC: 514.53
# Tested order: (0, 1, 1), seasonal_order: (1, 1, 1, 12), AIC: 499.30
# Tested order: (0, 1, 1), seasonal_order: (1, 1, 2, 12), AIC: 466.45
# Tested order: (0, 1, 1), seasonal_order: (1, 2, 0, 12), AIC: 584.21
# Tested order: (0, 1, 1), seasonal_order: (1, 2, 1, 12), AIC: 517.39
# Tested order: (0, 1, 1), seasonal_order: (1, 2, 2, 12), AIC: 483.14
# Tested order: (0, 1, 1), seasonal_order: (2, 0, 0, 12), AIC: 505.71
# Tested order: (0, 1, 1), seasonal_order: (2, 0, 1, 12), AIC: 503.39
# Tested order: (0, 1, 1), seasonal_order: (2, 0, 2, 12), AIC: 493.56
# Tested order: (0, 1, 1), seasonal_order: (2, 1, 0, 12), AIC: 483.60
# Tested order: (0, 1, 1), seasonal_order: (2, 1, 1, 12), AIC: 471.18
# Tested order: (0, 1, 1), seasonal_order: (2, 1, 2, 12), AIC: 468.45
# Tested order: (0, 1, 1), seasonal_order: (2, 2, 0, 12), AIC: 519.21
# Tested order: (0, 1, 1), seasonal_order: (2, 2, 1, 12), AIC: 490.13
# Tested order: (0, 1, 1), seasonal_order: (2, 2, 2, 12), AIC: 482.56
# Tested order: (0, 1, 2), seasonal_order: (0, 0, 0, 12), AIC: 649.43
# Tested order: (0, 1, 2), seasonal_order: (0, 0, 1, 12), AIC: 589.99
# Tested order: (0, 1, 2), seasonal_order: (0, 0, 2, 12), AIC: 542.65
# Tested order: (0, 1, 2), seasonal_order: (0, 1, 0, 12), AIC: 573.31
# Tested order: (0, 1, 2), seasonal_order: (0, 1, 1, 12), AIC: 489.37
# Tested order: (0, 1, 2), seasonal_order: (0, 1, 2, 12), AIC: 461.05
# Tested order: (0, 1, 2), seasonal_order: (0, 2, 0, 12), AIC: 703.79
# Tested order: (0, 1, 2), seasonal_order: (0, 2, 1, 12), AIC: 532.83
# Tested order: (0, 1, 2), seasonal_order: (0, 2, 2, 12), AIC: 468.28
# Tested order: (0, 1, 2), seasonal_order: (1, 0, 0, 12), AIC: 559.41
# Tested order: (0, 1, 2), seasonal_order: (1, 0, 1, 12), AIC: 523.56
# Tested order: (0, 1, 2), seasonal_order: (1, 0, 2, 12), AIC: 494.11
# Tested order: (0, 1, 2), seasonal_order: (1, 1, 0, 12), AIC: 515.29
# Tested order: (0, 1, 2), seasonal_order: (1, 1, 1, 12), AIC: 497.20
# Tested order: (0, 1, 2), seasonal_order: (1, 1, 2, 12), AIC: 462.90
# Tested order: (0, 1, 2), seasonal_order: (1, 2, 0, 12), AIC: 584.75
# Tested order: (0, 1, 2), seasonal_order: (1, 2, 1, 12), AIC: 515.04
# Tested order: (0, 1, 2), seasonal_order: (1, 2, 2, 12), AIC: 480.67
# Tested order: (0, 1, 2), seasonal_order: (2, 0, 0, 12), AIC: 505.81
# Tested order: (0, 1, 2), seasonal_order: (2, 0, 1, 12), AIC: 504.70
# Tested order: (0, 1, 2), seasonal_order: (2, 0, 2, 12), AIC: 492.37
# Tested order: (0, 1, 2), seasonal_order: (2, 1, 0, 12), AIC: 484.55
# Tested order: (0, 1, 2), seasonal_order: (2, 1, 1, 12), AIC: 476.02
# Tested order: (0, 1, 2), seasonal_order: (2, 1, 2, 12), AIC: 464.90
# Tested order: (0, 1, 2), seasonal_order: (2, 2, 0, 12), AIC: 519.77
# Tested order: (0, 1, 2), seasonal_order: (2, 2, 1, 12), AIC: 491.22
# Tested order: (0, 1, 2), seasonal_order: (2, 2, 2, 12), AIC: 480.59
# Tested order: (0, 2, 0), seasonal_order: (0, 0, 0, 12), AIC: 790.62
# Tested order: (0, 2, 0), seasonal_order: (0, 0, 1, 12), AIC: 739.78
# Tested order: (0, 2, 0), seasonal_order: (0, 0, 2, 12), AIC: 695.36
# Tested order: (0, 2, 0), seasonal_order: (0, 1, 0, 12), AIC: 835.47
# Tested order: (0, 2, 0), seasonal_order: (0, 1, 1, 12), AIC: 709.18
# Tested order: (0, 2, 0), seasonal_order: (0, 1, 2, 12), AIC: 673.46
# Tested order: (0, 2, 0), seasonal_order: (0, 2, 0, 12), AIC: 966.51
# Tested order: (0, 2, 0), seasonal_order: (0, 2, 1, 12), AIC: 756.72
# Tested order: (0, 2, 0), seasonal_order: (0, 2, 2, 12), AIC: 652.18
# Tested order: (0, 2, 0), seasonal_order: (1, 0, 0, 12), AIC: 743.74
# Tested order: (0, 2, 0), seasonal_order: (1, 0, 1, 12), AIC: 741.83
# Tested order: (0, 2, 0), seasonal_order: (1, 0, 2, 12), AIC: 696.90
# Tested order: (0, 2, 0), seasonal_order: (1, 1, 0, 12), AIC: 740.40
# Tested order: (0, 2, 0), seasonal_order: (1, 1, 1, 12), AIC: 722.11
# Tested order: (0, 2, 0), seasonal_order: (1, 1, 2, 12), AIC: 673.62
# Tested order: (0, 2, 0), seasonal_order: (1, 2, 0, 12), AIC: 811.97
# Tested order: (0, 2, 0), seasonal_order: (1, 2, 1, 12), AIC: 728.84
# Tested order: (0, 2, 0), seasonal_order: (1, 2, 2, 12), AIC: 674.43
# Tested order: (0, 2, 0), seasonal_order: (2, 0, 0, 12), AIC: 697.44
# Tested order: (0, 2, 0), seasonal_order: (2, 0, 1, 12), AIC: 699.43
# Tested order: (0, 2, 0), seasonal_order: (2, 0, 2, 12), AIC: 698.01
# Tested order: (0, 2, 0), seasonal_order: (2, 1, 0, 12), AIC: 687.61
# Tested order: (0, 2, 0), seasonal_order: (2, 1, 1, 12), AIC: 678.48
# Tested order: (0, 2, 0), seasonal_order: (2, 1, 2, 12), AIC: 675.40
# Tested order: (0, 2, 0), seasonal_order: (2, 2, 0, 12), AIC: 714.44
# Tested order: (0, 2, 0), seasonal_order: (2, 2, 1, 12), AIC: 677.03
# Tested order: (0, 2, 0), seasonal_order: (2, 2, 2, 12), AIC: 670.62
# Tested order: (0, 2, 1), seasonal_order: (0, 0, 0, 12), AIC: 658.74
# Tested order: (0, 2, 1), seasonal_order: (0, 0, 1, 12), AIC: 598.10
# Tested order: (0, 2, 1), seasonal_order: (0, 0, 2, 12), AIC: 553.34
# Tested order: (0, 2, 1), seasonal_order: (0, 1, 0, 12), AIC: 645.37
# Tested order: (0, 2, 1), seasonal_order: (0, 1, 1, 12), AIC: 535.63
# Tested order: (0, 2, 1), seasonal_order: (0, 1, 2, 12), AIC: 510.74
# Tested order: (0, 2, 1), seasonal_order: (0, 2, 0, 12), AIC: 786.23
# Tested order: (0, 2, 1), seasonal_order: (0, 2, 1, 12), AIC: 593.18
# Tested order: (0, 2, 1), seasonal_order: (0, 2, 2, 12), AIC: 504.13
# Tested order: (0, 2, 1), seasonal_order: (1, 0, 0, 12), AIC: 594.32
# Tested order: (0, 2, 1), seasonal_order: (1, 0, 1, 12), AIC: 572.47
# Tested order: (0, 2, 1), seasonal_order: (1, 0, 2, 12), AIC: 544.87
# Tested order: (0, 2, 1), seasonal_order: (1, 1, 0, 12), AIC: 567.42
# Tested order: (0, 2, 1), seasonal_order: (1, 1, 1, 12), AIC: 537.63
# Tested order: (0, 2, 1), seasonal_order: (1, 1, 2, 12), AIC: 510.58
# Tested order: (0, 2, 1), seasonal_order: (1, 2, 0, 12), AIC: 648.37
# Tested order: (0, 2, 1), seasonal_order: (1, 2, 1, 12), AIC: 568.03
# Tested order: (0, 2, 1), seasonal_order: (1, 2, 2, 12), AIC: 525.66
# Tested order: (0, 2, 1), seasonal_order: (2, 0, 0, 12), AIC: 545.86
# Tested order: (0, 2, 1), seasonal_order: (2, 0, 1, 12), AIC: 547.35
# Tested order: (0, 2, 1), seasonal_order: (2, 0, 2, 12), AIC: 538.58
# Tested order: (0, 2, 1), seasonal_order: (2, 1, 0, 12), AIC: 528.17
# Tested order: (0, 2, 1), seasonal_order: (2, 1, 1, 12), AIC: 521.37
# Tested order: (0, 2, 1), seasonal_order: (2, 1, 2, 12), AIC: 514.94
# Tested order: (0, 2, 1), seasonal_order: (2, 2, 0, 12), AIC: 564.54
# Tested order: (0, 2, 1), seasonal_order: (2, 2, 1, 12), AIC: 532.97
# Tested order: (0, 2, 1), seasonal_order: (2, 2, 2, 12), AIC: 522.46
# Tested order: (0, 2, 2), seasonal_order: (0, 0, 0, 12), AIC: 657.76
# Tested order: (0, 2, 2), seasonal_order: (0, 0, 1, 12), AIC: 591.52
# Tested order: (0, 2, 2), seasonal_order: (0, 0, 2, 12), AIC: 543.05
# Tested order: (0, 2, 2), seasonal_order: (0, 1, 0, 12), AIC: 575.99
# Tested order: (0, 2, 2), seasonal_order: (0, 1, 1, 12), AIC: 478.30
# Tested order: (0, 2, 2), seasonal_order: (0, 1, 2, 12), AIC: 455.28
# Tested order: (0, 2, 2), seasonal_order: (0, 2, 0, 12), AIC: 709.17
# Tested order: (0, 2, 2), seasonal_order: (0, 2, 1, 12), AIC: 534.97
# Tested order: (0, 2, 2), seasonal_order: (0, 2, 2, 12), AIC: 457.27
# Tested order: (0, 2, 2), seasonal_order: (1, 0, 0, 12), AIC: 568.06
# Tested order: (0, 2, 2), seasonal_order: (1, 0, 1, 12), AIC: 512.25
# Tested order: (0, 2, 2), seasonal_order: (1, 0, 2, 12), AIC: 490.08
# Tested order: (0, 2, 2), seasonal_order: (1, 1, 0, 12), AIC: 514.62
# Tested order: (0, 2, 2), seasonal_order: (1, 1, 1, 12), AIC: 484.38
# Tested order: (0, 2, 2), seasonal_order: (1, 1, 2, 12), AIC: 456.30
# Tested order: (0, 2, 2), seasonal_order: (1, 2, 0, 12), AIC: 589.82
# Tested order: (0, 2, 2), seasonal_order: (1, 2, 1, 12), AIC: 510.62
# Tested order: (0, 2, 2), seasonal_order: (1, 2, 2, 12), AIC: 473.11
# Tested order: (0, 2, 2), seasonal_order: (2, 0, 0, 12), AIC: 508.57
# Tested order: (0, 2, 2), seasonal_order: (2, 0, 1, 12), AIC: 501.79
# Tested order: (0, 2, 2), seasonal_order: (2, 0, 2, 12), AIC: 486.94
# Tested order: (0, 2, 2), seasonal_order: (2, 1, 0, 12), AIC: 484.33
# Tested order: (0, 2, 2), seasonal_order: (2, 1, 1, 12), AIC: 465.62
# Tested order: (0, 2, 2), seasonal_order: (2, 1, 2, 12), AIC: 458.73
# Tested order: (0, 2, 2), seasonal_order: (2, 2, 0, 12), AIC: 522.53
# Tested order: (0, 2, 2), seasonal_order: (2, 2, 1, 12), AIC: 490.19
# Tested order: (0, 2, 2), seasonal_order: (2, 2, 2, 12), AIC: 477.70
# Tested order: (1, 0, 0), seasonal_order: (0, 0, 0, 12), AIC: 663.34
# Tested order: (1, 0, 0), seasonal_order: (0, 0, 1, 12), AIC: 602.51
# Tested order: (1, 0, 0), seasonal_order: (0, 0, 2, 12), AIC: 557.28
# Tested order: (1, 0, 0), seasonal_order: (0, 1, 0, 12), AIC: 628.76
# Tested order: (1, 0, 0), seasonal_order: (0, 1, 1, 12), AIC: 535.12
# Tested order: (1, 0, 0), seasonal_order: (0, 1, 2, 12), AIC: 512.03
# Tested order: (1, 0, 0), seasonal_order: (0, 2, 0, 12), AIC: 717.76
# Tested order: (1, 0, 0), seasonal_order: (0, 2, 1, 12), AIC: 568.61
# Tested order: (1, 0, 0), seasonal_order: (0, 2, 2, 12), AIC: 501.81
# Tested order: (1, 0, 0), seasonal_order: (1, 0, 0, 12), AIC: 591.54
# Tested order: (1, 0, 0), seasonal_order: (1, 0, 1, 12), AIC: 575.55
# Tested order: (1, 0, 0), seasonal_order: (1, 0, 2, 12), AIC: 546.41
# Tested order: (1, 0, 0), seasonal_order: (1, 1, 0, 12), AIC: 554.79
# Tested order: (1, 0, 0), seasonal_order: (1, 1, 1, 12), AIC: 537.12
# Tested order: (1, 0, 0), seasonal_order: (1, 1, 2, 12), AIC: 512.78
# Tested order: (1, 0, 0), seasonal_order: (1, 2, 0, 12), AIC: 606.96
# Tested order: (1, 0, 0), seasonal_order: (1, 2, 1, 12), AIC: 555.02
# Tested order: (1, 0, 0), seasonal_order: (1, 2, 2, 12), AIC: 518.27
# Tested order: (1, 0, 0), seasonal_order: (2, 0, 0, 12), AIC: 542.69
# Tested order: (1, 0, 0), seasonal_order: (2, 0, 1, 12), AIC: 543.74
# Tested order: (1, 0, 0), seasonal_order: (2, 0, 2, 12), AIC: 539.50
# Tested order: (1, 0, 0), seasonal_order: (2, 1, 0, 12), AIC: 519.35
# Tested order: (1, 0, 0), seasonal_order: (2, 1, 1, 12), AIC: 514.47
# Tested order: (1, 0, 0), seasonal_order: (2, 1, 2, 12), AIC: 514.68
# Tested order: (1, 0, 0), seasonal_order: (2, 2, 0, 12), AIC: 542.57
# Tested order: (1, 0, 0), seasonal_order: (2, 2, 1, 12), AIC: 518.45
# Tested order: (1, 0, 0), seasonal_order: (2, 2, 2, 12), AIC: 514.52
# Tested order: (1, 0, 1), seasonal_order: (0, 0, 0, 12), AIC: 661.42
# Tested order: (1, 0, 1), seasonal_order: (0, 0, 1, 12), AIC: 598.63
# Tested order: (1, 0, 1), seasonal_order: (0, 0, 2, 12), AIC: 547.36
# Tested order: (1, 0, 1), seasonal_order: (0, 1, 0, 12), AIC: 579.05
# Tested order: (1, 0, 1), seasonal_order: (0, 1, 1, 12), AIC: 492.79
# Tested order: (1, 0, 1), seasonal_order: (0, 1, 2, 12), AIC: 468.66
# Tested order: (1, 0, 1), seasonal_order: (0, 2, 0, 12), AIC: 710.36
# Tested order: (1, 0, 1), seasonal_order: (0, 2, 1, 12), AIC: 537.75
# Tested order: (1, 0, 1), seasonal_order: (0, 2, 2, 12), AIC: 470.64
# Tested order: (1, 0, 1), seasonal_order: (1, 0, 0, 12), AIC: 562.87
# Tested order: (1, 0, 1), seasonal_order: (1, 0, 1, 12), AIC: 529.04
# Tested order: (1, 0, 1), seasonal_order: (1, 0, 2, 12), AIC: 501.26
# Tested order: (1, 0, 1), seasonal_order: (1, 1, 0, 12), AIC: 514.94
# Tested order: (1, 0, 1), seasonal_order: (1, 1, 1, 12), AIC: 503.86
# Tested order: (1, 0, 1), seasonal_order: (1, 1, 2, 12), AIC: 470.59
# Tested order: (1, 0, 1), seasonal_order: (1, 2, 0, 12), AIC: 583.44
# Tested order: (1, 0, 1), seasonal_order: (1, 2, 1, 12), AIC: 520.28
# Tested order: (1, 0, 1), seasonal_order: (1, 2, 2, 12), AIC: 485.92
# Tested order: (1, 0, 1), seasonal_order: (2, 0, 0, 12), AIC: 507.69
# Tested order: (1, 0, 1), seasonal_order: (2, 0, 1, 12), AIC: 505.83
# Tested order: (1, 0, 1), seasonal_order: (2, 0, 2, 12), AIC: 497.99
# Tested order: (1, 0, 1), seasonal_order: (2, 1, 0, 12), AIC: 484.65
# Tested order: (1, 0, 1), seasonal_order: (2, 1, 1, 12), AIC: 476.85
# Tested order: (1, 0, 1), seasonal_order: (2, 1, 2, 12), AIC: 472.93
# Tested order: (1, 0, 1), seasonal_order: (2, 2, 0, 12), AIC: 517.87
# Tested order: (1, 0, 1), seasonal_order: (2, 2, 1, 12), AIC: 488.69
# Tested order: (1, 0, 1), seasonal_order: (2, 2, 2, 12), AIC: 485.30
# Tested order: (1, 0, 2), seasonal_order: (0, 0, 0, 12), AIC: 653.97
# Tested order: (1, 0, 2), seasonal_order: (0, 0, 1, 12), AIC: 595.41
# Tested order: (1, 0, 2), seasonal_order: (0, 0, 2, 12), AIC: 547.05
# Tested order: (1, 0, 2), seasonal_order: (0, 1, 0, 12), AIC: 576.73
# Tested order: (1, 0, 2), seasonal_order: (0, 1, 1, 12), AIC: 493.66
# Tested order: (1, 0, 2), seasonal_order: (0, 1, 2, 12), AIC: 467.18
# Tested order: (1, 0, 2), seasonal_order: (0, 2, 0, 12), AIC: 706.75
# Tested order: (1, 0, 2), seasonal_order: (0, 2, 1, 12), AIC: 535.76
# Tested order: (1, 0, 2), seasonal_order: (0, 2, 2, 12), AIC: 472.45
# Tested order: (1, 0, 2), seasonal_order: (1, 0, 0, 12), AIC: 560.78
# Tested order: (1, 0, 2), seasonal_order: (1, 0, 1, 12), AIC: 528.24
# Tested order: (1, 0, 2), seasonal_order: (1, 0, 2, 12), AIC: 498.82
# Tested order: (1, 0, 2), seasonal_order: (1, 1, 0, 12), AIC: 515.77
# Tested order: (1, 0, 2), seasonal_order: (1, 1, 1, 12), AIC: 502.57
# Tested order: (1, 0, 2), seasonal_order: (1, 1, 2, 12), AIC: 469.16
# Tested order: (1, 0, 2), seasonal_order: (1, 2, 0, 12), AIC: 584.02
# Tested order: (1, 0, 2), seasonal_order: (1, 2, 1, 12), AIC: 518.56
# Tested order: (1, 0, 2), seasonal_order: (1, 2, 2, 12), AIC: 484.79
# Tested order: (1, 0, 2), seasonal_order: (2, 0, 0, 12), AIC: 507.81
# Tested order: (1, 0, 2), seasonal_order: (2, 0, 1, 12), AIC: 507.07
# Tested order: (1, 0, 2), seasonal_order: (2, 0, 2, 12), AIC: 498.83
# Tested order: (1, 0, 2), seasonal_order: (2, 1, 0, 12), AIC: 485.68
# Tested order: (1, 0, 2), seasonal_order: (2, 1, 1, 12), AIC: 474.34
# Tested order: (1, 0, 2), seasonal_order: (2, 1, 2, 12), AIC: 471.17
# Tested order: (1, 0, 2), seasonal_order: (2, 2, 0, 12), AIC: 518.62
# Tested order: (1, 0, 2), seasonal_order: (2, 2, 1, 12), AIC: 490.01
# Tested order: (1, 0, 2), seasonal_order: (2, 2, 2, 12), AIC: 484.01
# Tested order: (1, 1, 0), seasonal_order: (0, 0, 0, 12), AIC: 659.66
# Tested order: (1, 1, 0), seasonal_order: (0, 0, 1, 12), AIC: 595.93
# Tested order: (1, 1, 0), seasonal_order: (0, 0, 2, 12), AIC: 544.49
# Tested order: (1, 1, 0), seasonal_order: (0, 1, 0, 12), AIC: 609.54
# Tested order: (1, 1, 0), seasonal_order: (0, 1, 1, 12), AIC: 504.66
# Tested order: (1, 1, 0), seasonal_order: (0, 1, 2, 12), AIC: 481.22
# Tested order: (1, 1, 0), seasonal_order: (0, 2, 0, 12), AIC: 752.86
# Tested order: (1, 1, 0), seasonal_order: (0, 2, 1, 12), AIC: 560.36
# Tested order: (1, 1, 0), seasonal_order: (0, 2, 2, 12), AIC: 478.41
# Tested order: (1, 1, 0), seasonal_order: (1, 0, 0, 12), AIC: 571.49
# Tested order: (1, 1, 0), seasonal_order: (1, 0, 1, 12), AIC: 542.37
# Tested order: (1, 1, 0), seasonal_order: (1, 0, 2, 12), AIC: 514.93
# Tested order: (1, 1, 0), seasonal_order: (1, 1, 0, 12), AIC: 529.23
# Tested order: (1, 1, 0), seasonal_order: (1, 1, 1, 12), AIC: 506.66
# Tested order: (1, 1, 0), seasonal_order: (1, 1, 2, 12), AIC: 482.60
# Tested order: (1, 1, 0), seasonal_order: (1, 2, 0, 12), AIC: 607.47
# Tested order: (1, 1, 0), seasonal_order: (1, 2, 1, 12), AIC: 535.57
# Tested order: (1, 1, 0), seasonal_order: (1, 2, 2, 12), AIC: 497.68
# Tested order: (1, 1, 0), seasonal_order: (2, 0, 0, 12), AIC: 515.98
# Tested order: (1, 1, 0), seasonal_order: (2, 0, 1, 12), AIC: 515.66
# Tested order: (1, 1, 0), seasonal_order: (2, 0, 2, 12), AIC: 509.13
# Tested order: (1, 1, 0), seasonal_order: (2, 1, 0, 12), AIC: 493.59
# Tested order: (1, 1, 0), seasonal_order: (2, 1, 1, 12), AIC: 485.08
# Tested order: (1, 1, 0), seasonal_order: (2, 1, 2, 12), AIC: 485.53
# Tested order: (1, 1, 0), seasonal_order: (2, 2, 0, 12), AIC: 528.37
# Tested order: (1, 1, 0), seasonal_order: (2, 2, 1, 12), AIC: 497.12
# Tested order: (1, 1, 0), seasonal_order: (2, 2, 2, 12), AIC: 495.26
# Tested order: (1, 1, 1), seasonal_order: (0, 0, 0, 12), AIC: 658.43
# Tested order: (1, 1, 1), seasonal_order: (0, 0, 1, 12), AIC: 593.43
# Tested order: (1, 1, 1), seasonal_order: (0, 0, 2, 12), AIC: 543.73
# Tested order: (1, 1, 1), seasonal_order: (0, 1, 0, 12), AIC: 576.63
# Tested order: (1, 1, 1), seasonal_order: (0, 1, 1, 12), AIC: 490.34
# Tested order: (1, 1, 1), seasonal_order: (0, 1, 2, 12), AIC: 465.76
# Tested order: (1, 1, 1), seasonal_order: (0, 2, 0, 12), AIC: 708.37
# Tested order: (1, 1, 1), seasonal_order: (0, 2, 1, 12), AIC: 536.12
# Tested order: (1, 1, 1), seasonal_order: (0, 2, 2, 12), AIC: 468.50
# Tested order: (1, 1, 1), seasonal_order: (1, 0, 0, 12), AIC: 556.83
# Tested order: (1, 1, 1), seasonal_order: (1, 0, 1, 12), AIC: 524.32
# Tested order: (1, 1, 1), seasonal_order: (1, 0, 2, 12), AIC: 497.91
# Tested order: (1, 1, 1), seasonal_order: (1, 1, 0, 12), AIC: 512.96
# Tested order: (1, 1, 1), seasonal_order: (1, 1, 1, 12), AIC: 500.57
# Tested order: (1, 1, 1), seasonal_order: (1, 1, 2, 12), AIC: 467.74
# Tested order: (1, 1, 1), seasonal_order: (1, 2, 0, 12), AIC: 581.69
# Tested order: (1, 1, 1), seasonal_order: (1, 2, 1, 12), AIC: 518.22
# Tested order: (1, 1, 1), seasonal_order: (1, 2, 2, 12), AIC: 484.26
# Tested order: (1, 1, 1), seasonal_order: (2, 0, 0, 12), AIC: 503.74
# Tested order: (1, 1, 1), seasonal_order: (2, 0, 1, 12), AIC: 502.52
# Tested order: (1, 1, 1), seasonal_order: (2, 0, 2, 12), AIC: 494.83
# Tested order: (1, 1, 1), seasonal_order: (2, 1, 0, 12), AIC: 481.93
# Tested order: (1, 1, 1), seasonal_order: (2, 1, 1, 12), AIC: 473.15
# Tested order: (1, 1, 1), seasonal_order: (2, 1, 2, 12), AIC: 469.74
# Tested order: (1, 1, 1), seasonal_order: (2, 2, 0, 12), AIC: 516.04
# Tested order: (1, 1, 1), seasonal_order: (2, 2, 1, 12), AIC: 487.53
# Tested order: (1, 1, 1), seasonal_order: (2, 2, 2, 12), AIC: 483.45
# Tested order: (1, 1, 2), seasonal_order: (0, 0, 0, 12), AIC: 653.32
# Tested order: (1, 1, 2), seasonal_order: (0, 0, 1, 12), AIC: 587.23
# Tested order: (1, 1, 2), seasonal_order: (0, 0, 2, 12), AIC: 536.29
# Tested order: (1, 1, 2), seasonal_order: (0, 1, 0, 12), AIC: 575.31
# Tested order: (1, 1, 2), seasonal_order: (0, 1, 1, 12), AIC: 491.33
# Tested order: (1, 1, 2), seasonal_order: (0, 1, 2, 12), AIC: 463.03
# Tested order: (1, 1, 2), seasonal_order: (0, 2, 0, 12), AIC: 705.66
# Tested order: (1, 1, 2), seasonal_order: (0, 2, 1, 12), AIC: 534.70
# Tested order: (1, 1, 2), seasonal_order: (0, 2, 2, 12), AIC: 469.00
# Tested order: (1, 1, 2), seasonal_order: (1, 0, 0, 12), AIC: 558.75
# Tested order: (1, 1, 2), seasonal_order: (1, 0, 1, 12), AIC: 524.50
# Tested order: (1, 1, 2), seasonal_order: (1, 0, 2, 12), AIC: 496.04
# Tested order: (1, 1, 2), seasonal_order: (1, 1, 0, 12), AIC: 514.93
# Tested order: (1, 1, 2), seasonal_order: (1, 1, 1, 12), AIC: 499.19
# Tested order: (1, 1, 2), seasonal_order: (1, 1, 2, 12), AIC: 464.85
# Tested order: (1, 1, 2), seasonal_order: (1, 2, 0, 12), AIC: 583.66
# Tested order: (1, 1, 2), seasonal_order: (1, 2, 1, 12), AIC: 516.90
# Tested order: (1, 1, 2), seasonal_order: (1, 2, 2, 12), AIC: 482.54
# Tested order: (1, 1, 2), seasonal_order: (2, 0, 0, 12), AIC: 505.73
# Tested order: (1, 1, 2), seasonal_order: (2, 0, 1, 12), AIC: 504.34
# Tested order: (1, 1, 2), seasonal_order: (2, 0, 2, 12), AIC: 494.23
# Tested order: (1, 1, 2), seasonal_order: (2, 1, 0, 12), AIC: 483.89
# Tested order: (1, 1, 2), seasonal_order: (2, 1, 1, 12), AIC: 475.14
# Tested order: (1, 1, 2), seasonal_order: (2, 1, 2, 12), AIC: 466.85
# Tested order: (1, 1, 2), seasonal_order: (2, 2, 0, 12), AIC: 517.88
# Tested order: (1, 1, 2), seasonal_order: (2, 2, 1, 12), AIC: 489.49
# Tested order: (1, 1, 2), seasonal_order: (2, 2, 2, 12), AIC: 482.38
# Tested order: (1, 2, 0), seasonal_order: (0, 0, 0, 12), AIC: 711.26
# Tested order: (1, 2, 0), seasonal_order: (0, 0, 1, 12), AIC: 662.88
# Tested order: (1, 2, 0), seasonal_order: (0, 0, 2, 12), AIC: 615.93
# Tested order: (1, 2, 0), seasonal_order: (0, 1, 0, 12), AIC: 737.21
# Tested order: (1, 2, 0), seasonal_order: (0, 1, 1, 12), AIC: 615.65
# Tested order: (1, 2, 0), seasonal_order: (0, 1, 2, 12), AIC: 585.43
# Tested order: (1, 2, 0), seasonal_order: (0, 2, 0, 12), AIC: 871.02
# Tested order: (1, 2, 0), seasonal_order: (0, 2, 1, 12), AIC: 665.58
# Tested order: (1, 2, 0), seasonal_order: (0, 2, 2, 12), AIC: 570.83
# Tested order: (1, 2, 0), seasonal_order: (1, 0, 0, 12), AIC: 661.07
# Tested order: (1, 2, 0), seasonal_order: (1, 0, 1, 12), AIC: 657.17
# Tested order: (1, 2, 0), seasonal_order: (1, 0, 2, 12), AIC: 615.25
# Tested order: (1, 2, 0), seasonal_order: (1, 1, 0, 12), AIC: 642.67
# Tested order: (1, 2, 0), seasonal_order: (1, 1, 1, 12), AIC: 617.65
# Tested order: (1, 2, 0), seasonal_order: (1, 1, 2, 12), AIC: 586.74
# Tested order: (1, 2, 0), seasonal_order: (1, 2, 0, 12), AIC: 718.19
# Tested order: (1, 2, 0), seasonal_order: (1, 2, 1, 12), AIC: 640.91
# Tested order: (1, 2, 0), seasonal_order: (1, 2, 2, 12), AIC: 593.26
# Tested order: (1, 2, 0), seasonal_order: (2, 0, 0, 12), AIC: 611.36
# Tested order: (1, 2, 0), seasonal_order: (2, 0, 1, 12), AIC: 613.27
# Tested order: (1, 2, 0), seasonal_order: (2, 0, 2, 12), AIC: 614.16
# Tested order: (1, 2, 0), seasonal_order: (2, 1, 0, 12), AIC: 593.85
# Tested order: (1, 2, 0), seasonal_order: (2, 1, 1, 12), AIC: 586.39
# Tested order: (1, 2, 0), seasonal_order: (2, 1, 2, 12), AIC: 587.49
# Tested order: (1, 2, 0), seasonal_order: (2, 2, 0, 12), AIC: 620.32
# Tested order: (1, 2, 0), seasonal_order: (2, 2, 1, 12), AIC: 588.80
# Tested order: (1, 2, 0), seasonal_order: (2, 2, 2, 12), AIC: 586.80
# Tested order: (1, 2, 1), seasonal_order: (0, 0, 0, 12), AIC: 660.47
# Tested order: (1, 2, 1), seasonal_order: (0, 0, 1, 12), AIC: 595.81
# Tested order: (1, 2, 1), seasonal_order: (0, 0, 2, 12), AIC: 545.48
# Tested order: (1, 2, 1), seasonal_order: (0, 1, 0, 12), AIC: 609.99
# Tested order: (1, 2, 1), seasonal_order: (0, 1, 1, 12), AIC: 507.44
# Tested order: (1, 2, 1), seasonal_order: (0, 1, 2, 12), AIC: 482.80
# Tested order: (1, 2, 1), seasonal_order: (0, 2, 0, 12), AIC: 751.11
# Tested order: (1, 2, 1), seasonal_order: (0, 2, 1, 12), AIC: 562.66
# Tested order: (1, 2, 1), seasonal_order: (0, 2, 2, 12), AIC: 481.99
# Tested order: (1, 2, 1), seasonal_order: (1, 0, 0, 12), AIC: 576.21
# Tested order: (1, 2, 1), seasonal_order: (1, 0, 1, 12), AIC: 546.83
# Tested order: (1, 2, 1), seasonal_order: (1, 0, 2, 12), AIC: 518.00
# Tested order: (1, 2, 1), seasonal_order: (1, 1, 0, 12), AIC: 534.02
# Tested order: (1, 2, 1), seasonal_order: (1, 1, 1, 12), AIC: 509.45
# Tested order: (1, 2, 1), seasonal_order: (1, 1, 2, 12), AIC: 483.50
# Tested order: (1, 2, 1), seasonal_order: (1, 2, 0, 12), AIC: 611.32
# Tested order: (1, 2, 1), seasonal_order: (1, 2, 1, 12), AIC: 539.65
# Tested order: (1, 2, 1), seasonal_order: (1, 2, 2, 12), AIC: 499.97
# Tested order: (1, 2, 1), seasonal_order: (2, 0, 0, 12), AIC: 521.13
# Tested order: (1, 2, 1), seasonal_order: (2, 0, 1, 12), AIC: 521.74
# Tested order: (1, 2, 1), seasonal_order: (2, 0, 2, 12), AIC: 512.94
# Tested order: (1, 2, 1), seasonal_order: (2, 1, 0, 12), AIC: 498.47
# Tested order: (1, 2, 1), seasonal_order: (2, 1, 1, 12), AIC: 491.87
# Tested order: (1, 2, 1), seasonal_order: (2, 1, 2, 12), AIC: 488.97
# Tested order: (1, 2, 1), seasonal_order: (2, 2, 0, 12), AIC: 532.22
# Tested order: (1, 2, 1), seasonal_order: (2, 2, 1, 12), AIC: 504.53
# Tested order: (1, 2, 1), seasonal_order: (2, 2, 2, 12), AIC: 498.63
# Tested order: (1, 2, 2), seasonal_order: (0, 0, 0, 12), AIC: 658.86
# Tested order: (1, 2, 2), seasonal_order: (0, 0, 1, 12), AIC: 591.34
# Tested order: (1, 2, 2), seasonal_order: (0, 0, 2, 12), AIC: 543.99
# Tested order: (1, 2, 2), seasonal_order: (0, 1, 0, 12), AIC: 576.01
# Tested order: (1, 2, 2), seasonal_order: (0, 1, 1, 12), AIC: 472.60
# Tested order: (1, 2, 2), seasonal_order: (0, 1, 2, 12), AIC: 450.32
# Tested order: (1, 2, 2), seasonal_order: (0, 2, 0, 12), AIC: 708.92
# Tested order: (1, 2, 2), seasonal_order: (0, 2, 1, 12), AIC: 534.70
# Tested order: (1, 2, 2), seasonal_order: (0, 2, 2, 12), AIC: 460.60
# Tested order: (1, 2, 2), seasonal_order: (1, 0, 0, 12), AIC: 558.44
# Tested order: (1, 2, 2), seasonal_order: (1, 0, 1, 12), AIC: 516.77
# Tested order: (1, 2, 2), seasonal_order: (1, 0, 2, 12), AIC: 485.88
# Tested order: (1, 2, 2), seasonal_order: (1, 1, 0, 12), AIC: 506.75
# Tested order: (1, 2, 2), seasonal_order: (1, 1, 1, 12), AIC: 474.73
# Tested order: (1, 2, 2), seasonal_order: (1, 1, 2, 12), AIC: 451.09
# Tested order: (1, 2, 2), seasonal_order: (1, 2, 0, 12), AIC: 585.83
# Tested order: (1, 2, 2), seasonal_order: (1, 2, 1, 12), AIC: 506.33
# Tested order: (1, 2, 2), seasonal_order: (1, 2, 2, 12), AIC: 452.49
# Tested order: (1, 2, 2), seasonal_order: (2, 0, 0, 12), AIC: 500.96
# Tested order: (1, 2, 2), seasonal_order: (2, 0, 1, 12), AIC: 490.95
# Tested order: (1, 2, 2), seasonal_order: (2, 0, 2, 12), AIC: 489.97
# Tested order: (1, 2, 2), seasonal_order: (2, 1, 0, 12), AIC: 474.90
# Tested order: (1, 2, 2), seasonal_order: (2, 1, 1, 12), AIC: 467.41
# Tested order: (1, 2, 2), seasonal_order: (2, 1, 2, 12), AIC: 461.59
# Tested order: (1, 2, 2), seasonal_order: (2, 2, 0, 12), AIC: 513.87
# Tested order: (1, 2, 2), seasonal_order: (2, 2, 1, 12), AIC: 487.17
# Tested order: (1, 2, 2), seasonal_order: (2, 2, 2, 12), AIC: 472.29
# Tested order: (2, 0, 0), seasonal_order: (0, 0, 0, 12), AIC: 661.41
# Tested order: (2, 0, 0), seasonal_order: (0, 0, 1, 12), AIC: 600.16
# Tested order: (2, 0, 0), seasonal_order: (0, 0, 2, 12), AIC: 549.84
# Tested order: (2, 0, 0), seasonal_order: (0, 1, 0, 12), AIC: 602.56
# Tested order: (2, 0, 0), seasonal_order: (0, 1, 1, 12), AIC: 508.34
# Tested order: (2, 0, 0), seasonal_order: (0, 1, 2, 12), AIC: 485.08
# Tested order: (2, 0, 0), seasonal_order: (0, 2, 0, 12), AIC: 713.58
# Tested order: (2, 0, 0), seasonal_order: (0, 2, 1, 12), AIC: 552.97
# Tested order: (2, 0, 0), seasonal_order: (0, 2, 2, 12), AIC: 480.98
# Tested order: (2, 0, 0), seasonal_order: (1, 0, 0, 12), AIC: 573.48
# Tested order: (2, 0, 0), seasonal_order: (1, 0, 1, 12), AIC: 544.14
# Tested order: (2, 0, 0), seasonal_order: (1, 0, 2, 12), AIC: 519.38
# Tested order: (2, 0, 0), seasonal_order: (1, 1, 0, 12), AIC: 526.92
# Tested order: (2, 0, 0), seasonal_order: (1, 1, 1, 12), AIC: 507.78
# Tested order: (2, 0, 0), seasonal_order: (1, 1, 2, 12), AIC: 486.40
# Tested order: (2, 0, 0), seasonal_order: (1, 2, 0, 12), AIC: 592.66
# Tested order: (2, 0, 0), seasonal_order: (1, 2, 1, 12), AIC: 531.30
# Tested order: (2, 0, 0), seasonal_order: (1, 2, 2, 12), AIC: 497.69
# Tested order: (2, 0, 0), seasonal_order: (2, 0, 0, 12), AIC: 517.85
# Tested order: (2, 0, 0), seasonal_order: (2, 0, 1, 12), AIC: 517.44
# Tested order: (2, 0, 0), seasonal_order: (2, 0, 2, 12), AIC: 510.97
# Tested order: (2, 0, 0), seasonal_order: (2, 1, 0, 12), AIC: 493.03
# Tested order: (2, 0, 0), seasonal_order: (2, 1, 1, 12), AIC: 484.93
# Tested order: (2, 0, 0), seasonal_order: (2, 1, 2, 12), AIC: 486.11
# Tested order: (2, 0, 0), seasonal_order: (2, 2, 0, 12), AIC: 522.15
# Tested order: (2, 0, 0), seasonal_order: (2, 2, 1, 12), AIC: 495.69
# Tested order: (2, 0, 0), seasonal_order: (2, 2, 2, 12), AIC: 492.69
# Tested order: (2, 0, 1), seasonal_order: (0, 0, 0, 12), AIC: 663.32
# Tested order: (2, 0, 1), seasonal_order: (0, 0, 1, 12), AIC: 599.74
# Tested order: (2, 0, 1), seasonal_order: (0, 0, 2, 12), AIC: 548.62
# Tested order: (2, 0, 1), seasonal_order: (0, 1, 0, 12), AIC: 579.89
# Tested order: (2, 0, 1), seasonal_order: (0, 1, 1, 12), AIC: 494.13
# Tested order: (2, 0, 1), seasonal_order: (0, 1, 2, 12), AIC: 469.91
# Tested order: (2, 0, 1), seasonal_order: (0, 2, 0, 12), AIC: 710.51
# Tested order: (2, 0, 1), seasonal_order: (0, 2, 1, 12), AIC: 538.36
# Tested order: (2, 0, 1), seasonal_order: (0, 2, 2, 12), AIC: 472.22
# Tested order: (2, 0, 1), seasonal_order: (1, 0, 0, 12), AIC: 576.26
# Tested order: (2, 0, 1), seasonal_order: (1, 0, 1, 12), AIC: 547.83
# Tested order: (2, 0, 1), seasonal_order: (1, 0, 2, 12), AIC: 533.91
# Tested order: (2, 0, 1), seasonal_order: (1, 1, 0, 12), AIC: 513.45
# Tested order: (2, 0, 1), seasonal_order: (1, 1, 1, 12), AIC: 505.15
# Tested order: (2, 0, 1), seasonal_order: (1, 1, 2, 12), AIC: 471.87
# Tested order: (2, 0, 1), seasonal_order: (1, 2, 0, 12), AIC: 580.99
# Tested order: (2, 0, 1), seasonal_order: (1, 2, 1, 12), AIC: 521.30
# Tested order: (2, 0, 1), seasonal_order: (1, 2, 2, 12), AIC: 487.19
# Tested order: (2, 0, 1), seasonal_order: (2, 0, 0, 12), AIC: 520.84
# Tested order: (2, 0, 1), seasonal_order: (2, 0, 1, 12), AIC: 523.21
# Tested order: (2, 0, 1), seasonal_order: (2, 0, 2, 12), AIC: 529.60
# Tested order: (2, 0, 1), seasonal_order: (2, 1, 0, 12), AIC: 483.10
# Tested order: (2, 0, 1), seasonal_order: (2, 1, 1, 12), AIC: 472.52
# Tested order: (2, 0, 1), seasonal_order: (2, 1, 2, 12), AIC: 474.08
# Tested order: (2, 0, 1), seasonal_order: (2, 2, 0, 12), AIC: 515.05
# Tested order: (2, 0, 1), seasonal_order: (2, 2, 1, 12), AIC: 487.44
# Tested order: (2, 0, 1), seasonal_order: (2, 2, 2, 12), AIC: 486.44
# Tested order: (2, 0, 2), seasonal_order: (0, 0, 0, 12), AIC: 655.76
# Tested order: (2, 0, 2), seasonal_order: (0, 0, 1, 12), AIC: 597.37
# Tested order: (2, 0, 2), seasonal_order: (0, 0, 2, 12), AIC: 548.53
# Tested order: (2, 0, 2), seasonal_order: (0, 1, 0, 12), AIC: 578.73
# Tested order: (2, 0, 2), seasonal_order: (0, 1, 1, 12), AIC: 495.03
# Tested order: (2, 0, 2), seasonal_order: (0, 1, 2, 12), AIC: 469.05
# Tested order: (2, 0, 2), seasonal_order: (0, 2, 0, 12), AIC: 708.68
# Tested order: (2, 0, 2), seasonal_order: (0, 2, 1, 12), AIC: 537.64
# Tested order: (2, 0, 2), seasonal_order: (0, 2, 2, 12), AIC: 472.59
# Tested order: (2, 0, 2), seasonal_order: (1, 0, 0, 12), AIC: 559.88
# Tested order: (2, 0, 2), seasonal_order: (1, 0, 1, 12), AIC: 530.12
# Tested order: (2, 0, 2), seasonal_order: (1, 0, 2, 12), AIC: 500.71
# Tested order: (2, 0, 2), seasonal_order: (1, 1, 0, 12), AIC: 515.42
# Tested order: (2, 0, 2), seasonal_order: (1, 1, 1, 12), AIC: 497.03
# Tested order: (2, 0, 2), seasonal_order: (1, 1, 2, 12), AIC: 471.10
# Tested order: (2, 0, 2), seasonal_order: (1, 2, 0, 12), AIC: 582.96
# Tested order: (2, 0, 2), seasonal_order: (1, 2, 1, 12), AIC: 520.44
# Tested order: (2, 0, 2), seasonal_order: (1, 2, 2, 12), AIC: 486.63
# Tested order: (2, 0, 2), seasonal_order: (2, 0, 0, 12), AIC: 507.73
# Tested order: (2, 0, 2), seasonal_order: (2, 0, 1, 12), AIC: 507.18
# Tested order: (2, 0, 2), seasonal_order: (2, 0, 2, 12), AIC: 499.06
# Tested order: (2, 0, 2), seasonal_order: (2, 1, 0, 12), AIC: 486.05
# Tested order: (2, 0, 2), seasonal_order: (2, 1, 1, 12), AIC: 474.46
# Tested order: (2, 0, 2), seasonal_order: (2, 1, 2, 12), AIC: 474.52
# Tested order: (2, 0, 2), seasonal_order: (2, 2, 0, 12), AIC: 516.89
# Tested order: (2, 0, 2), seasonal_order: (2, 2, 1, 12), AIC: 490.16
# Tested order: (2, 0, 2), seasonal_order: (2, 2, 2, 12), AIC: 489.60
# Tested order: (2, 1, 0), seasonal_order: (0, 0, 0, 12), AIC: 654.11
# Tested order: (2, 1, 0), seasonal_order: (0, 0, 1, 12), AIC: 596.77
# Tested order: (2, 1, 0), seasonal_order: (0, 0, 2, 12), AIC: 546.39
# Tested order: (2, 1, 0), seasonal_order: (0, 1, 0, 12), AIC: 598.05
# Tested order: (2, 1, 0), seasonal_order: (0, 1, 1, 12), AIC: 503.08
# Tested order: (2, 1, 0), seasonal_order: (0, 1, 2, 12), AIC: 478.42
# Tested order: (2, 1, 0), seasonal_order: (0, 2, 0, 12), AIC: 741.18
# Tested order: (2, 1, 0), seasonal_order: (0, 2, 1, 12), AIC: 557.13
# Tested order: (2, 1, 0), seasonal_order: (0, 2, 2, 12), AIC: 479.48
# Tested order: (2, 1, 0), seasonal_order: (1, 0, 0, 12), AIC: 567.06
# Tested order: (2, 1, 0), seasonal_order: (1, 0, 1, 12), AIC: 535.30
# Tested order: (2, 1, 0), seasonal_order: (1, 0, 2, 12), AIC: 510.67
# Tested order: (2, 1, 0), seasonal_order: (1, 1, 0, 12), AIC: 523.60
# Tested order: (2, 1, 0), seasonal_order: (1, 1, 1, 12), AIC: 502.66
# Tested order: (2, 1, 0), seasonal_order: (1, 1, 2, 12), AIC: 480.01
# Tested order: (2, 1, 0), seasonal_order: (1, 2, 0, 12), AIC: 598.16
# Tested order: (2, 1, 0), seasonal_order: (1, 2, 1, 12), AIC: 529.50
# Tested order: (2, 1, 0), seasonal_order: (1, 2, 2, 12), AIC: 495.61
# Tested order: (2, 1, 0), seasonal_order: (2, 0, 0, 12), AIC: 512.63
# Tested order: (2, 1, 0), seasonal_order: (2, 0, 1, 12), AIC: 509.68
# Tested order: (2, 1, 0), seasonal_order: (2, 0, 2, 12), AIC: 504.34
# Tested order: (2, 1, 0), seasonal_order: (2, 1, 0, 12), AIC: 490.35
# Tested order: (2, 1, 0), seasonal_order: (2, 1, 1, 12), AIC: 481.19
# Tested order: (2, 1, 0), seasonal_order: (2, 1, 2, 12), AIC: 479.78
# Tested order: (2, 1, 0), seasonal_order: (2, 2, 0, 12), AIC: 525.08
# Tested order: (2, 1, 0), seasonal_order: (2, 2, 1, 12), AIC: 493.57
# Tested order: (2, 1, 0), seasonal_order: (2, 2, 2, 12), AIC: 491.86
# Tested order: (2, 1, 1), seasonal_order: (0, 0, 0, 12), AIC: 656.05
# Tested order: (2, 1, 1), seasonal_order: (0, 0, 1, 12), AIC: 595.39
# Tested order: (2, 1, 1), seasonal_order: (0, 0, 2, 12), AIC: 545.33
# Tested order: (2, 1, 1), seasonal_order: (0, 1, 0, 12), AIC: 578.55
# Tested order: (2, 1, 1), seasonal_order: (0, 1, 1, 12), AIC: 492.34
# Tested order: (2, 1, 1), seasonal_order: (0, 1, 2, 12), AIC: 467.74
# Tested order: (2, 1, 1), seasonal_order: (0, 2, 0, 12), AIC: 710.37
# Tested order: (2, 1, 1), seasonal_order: (0, 2, 1, 12), AIC: 538.09
# Tested order: (2, 1, 1), seasonal_order: (0, 2, 2, 12), AIC: 473.26
# Tested order: (2, 1, 1), seasonal_order: (1, 0, 0, 12), AIC: 554.79
# Tested order: (2, 1, 1), seasonal_order: (1, 0, 1, 12), AIC: 526.32
# Tested order: (2, 1, 1), seasonal_order: (1, 0, 2, 12), AIC: 499.91
# Tested order: (2, 1, 1), seasonal_order: (1, 1, 0, 12), AIC: 512.85
# Tested order: (2, 1, 1), seasonal_order: (1, 1, 1, 12), AIC: 502.55
# Tested order: (2, 1, 1), seasonal_order: (1, 1, 2, 12), AIC: 469.19
# Tested order: (2, 1, 1), seasonal_order: (1, 2, 0, 12), AIC: 580.64
# Tested order: (2, 1, 1), seasonal_order: (1, 2, 1, 12), AIC: 520.14
# Tested order: (2, 1, 1), seasonal_order: (1, 2, 2, 12), AIC: 486.10
# Tested order: (2, 1, 1), seasonal_order: (2, 0, 0, 12), AIC: 503.48
# Tested order: (2, 1, 1), seasonal_order: (2, 0, 1, 12), AIC: 502.46
# Tested order: (2, 1, 1), seasonal_order: (2, 0, 2, 12), AIC: 496.77
# Tested order: (2, 1, 1), seasonal_order: (2, 1, 0, 12), AIC: 481.74
# Tested order: (2, 1, 1), seasonal_order: (2, 1, 1, 12), AIC: 472.78
# Tested order: (2, 1, 1), seasonal_order: (2, 1, 2, 12), AIC: 471.30
# Tested order: (2, 1, 1), seasonal_order: (2, 2, 0, 12), AIC: 514.89
# Tested order: (2, 1, 1), seasonal_order: (2, 2, 1, 12), AIC: 486.60
# Tested order: (2, 1, 1), seasonal_order: (2, 2, 2, 12), AIC: 485.25
# Tested order: (2, 1, 2), seasonal_order: (0, 0, 0, 12), AIC: 637.98
# Tested order: (2, 1, 2), seasonal_order: (0, 0, 1, 12), AIC: 586.55
# Tested order: (2, 1, 2), seasonal_order: (0, 0, 2, 12), AIC: 536.24
# Tested order: (2, 1, 2), seasonal_order: (0, 1, 0, 12), AIC: 577.21
# Tested order: (2, 1, 2), seasonal_order: (0, 1, 1, 12), AIC: 491.65
# Tested order: (2, 1, 2), seasonal_order: (0, 1, 2, 12), AIC: 464.86
# Tested order: (2, 1, 2), seasonal_order: (0, 2, 0, 12), AIC: 707.09
# Tested order: (2, 1, 2), seasonal_order: (0, 2, 1, 12), AIC: 536.10
# Tested order: (2, 1, 2), seasonal_order: (0, 2, 2, 12), AIC: 469.89
# Tested order: (2, 1, 2), seasonal_order: (1, 0, 0, 12), AIC: 556.20
# Tested order: (2, 1, 2), seasonal_order: (1, 0, 1, 12), AIC: 525.74
# Tested order: (2, 1, 2), seasonal_order: (1, 0, 2, 12), AIC: 487.62
# Tested order: (2, 1, 2), seasonal_order: (1, 1, 0, 12), AIC: 514.60
# Tested order: (2, 1, 2), seasonal_order: (1, 1, 1, 12), AIC: 500.99
# Tested order: (2, 1, 2), seasonal_order: (1, 1, 2, 12), AIC: 466.75
# Tested order: (2, 1, 2), seasonal_order: (1, 2, 0, 12), AIC: 582.58
# Tested order: (2, 1, 2), seasonal_order: (1, 2, 1, 12), AIC: 518.60
# Tested order: (2, 1, 2), seasonal_order: (1, 2, 2, 12), AIC: 484.23
# Tested order: (2, 1, 2), seasonal_order: (2, 0, 0, 12), AIC: 504.85
# Tested order: (2, 1, 2), seasonal_order: (2, 0, 1, 12), AIC: 504.04
# Tested order: (2, 1, 2), seasonal_order: (2, 0, 2, 12), AIC: 483.92
# Tested order: (2, 1, 2), seasonal_order: (2, 1, 0, 12), AIC: 482.56
# Tested order: (2, 1, 2), seasonal_order: (2, 1, 1, 12), AIC: 474.06
# Tested order: (2, 1, 2), seasonal_order: (2, 1, 2, 12), AIC: 468.77
# Tested order: (2, 1, 2), seasonal_order: (2, 2, 0, 12), AIC: 516.38
# Tested order: (2, 1, 2), seasonal_order: (2, 2, 1, 12), AIC: 487.80
# Tested order: (2, 1, 2), seasonal_order: (2, 2, 2, 12), AIC: 483.73
# Tested order: (2, 2, 0), seasonal_order: (0, 0, 0, 12), AIC: 699.40
# Tested order: (2, 2, 0), seasonal_order: (0, 0, 1, 12), AIC: 648.83
# Tested order: (2, 2, 0), seasonal_order: (0, 0, 2, 12), AIC: 599.63
# Tested order: (2, 2, 0), seasonal_order: (0, 1, 0, 12), AIC: 695.32
# Tested order: (2, 2, 0), seasonal_order: (0, 1, 1, 12), AIC: 587.44
# Tested order: (2, 2, 0), seasonal_order: (0, 1, 2, 12), AIC: 557.28
# Tested order: (2, 2, 0), seasonal_order: (0, 2, 0, 12), AIC: 835.00
# Tested order: (2, 2, 0), seasonal_order: (0, 2, 1, 12), AIC: 638.51
# Tested order: (2, 2, 0), seasonal_order: (0, 2, 2, 12), AIC: 548.85
# Tested order: (2, 2, 0), seasonal_order: (1, 0, 0, 12), AIC: 637.64
# Tested order: (2, 2, 0), seasonal_order: (1, 0, 1, 12), AIC: 623.59
# Tested order: (2, 2, 0), seasonal_order: (1, 0, 2, 12), AIC: 593.77
# Tested order: (2, 2, 0), seasonal_order: (1, 1, 0, 12), AIC: 605.04
# Tested order: (2, 2, 0), seasonal_order: (1, 1, 1, 12), AIC: 586.10
# Tested order: (2, 2, 0), seasonal_order: (1, 1, 2, 12), AIC: 558.27
# Tested order: (2, 2, 0), seasonal_order: (1, 2, 0, 12), AIC: 673.26
# Tested order: (2, 2, 0), seasonal_order: (1, 2, 1, 12), AIC: 604.34
# Tested order: (2, 2, 0), seasonal_order: (1, 2, 2, 12), AIC: 564.28
# Tested order: (2, 2, 0), seasonal_order: (2, 0, 0, 12), AIC: 586.33
# Tested order: (2, 2, 0), seasonal_order: (2, 0, 1, 12), AIC: 587.68
# Tested order: (2, 2, 0), seasonal_order: (2, 0, 2, 12), AIC: 585.50
# Tested order: (2, 2, 0), seasonal_order: (2, 1, 0, 12), AIC: 565.76
# Tested order: (2, 2, 0), seasonal_order: (2, 1, 1, 12), AIC: 559.51
# Tested order: (2, 2, 0), seasonal_order: (2, 1, 2, 12), AIC: 557.02
# Tested order: (2, 2, 0), seasonal_order: (2, 2, 0, 12), AIC: 590.92
# Tested order: (2, 2, 0), seasonal_order: (2, 2, 1, 12), AIC: 562.20
# Tested order: (2, 2, 0), seasonal_order: (2, 2, 2, 12), AIC: 558.76
# Tested order: (2, 2, 1), seasonal_order: (0, 0, 0, 12), AIC: 658.51
# Tested order: (2, 2, 1), seasonal_order: (0, 0, 1, 12), AIC: 596.90
# Tested order: (2, 2, 1), seasonal_order: (0, 0, 2, 12), AIC: 547.40
# Tested order: (2, 2, 1), seasonal_order: (0, 1, 0, 12), AIC: 602.14
# Tested order: (2, 2, 1), seasonal_order: (0, 1, 1, 12), AIC: 505.74
# Tested order: (2, 2, 1), seasonal_order: (0, 1, 2, 12), AIC: 479.84
# Tested order: (2, 2, 1), seasonal_order: (0, 2, 0, 12), AIC: 743.92
# Tested order: (2, 2, 1), seasonal_order: (0, 2, 1, 12), AIC: 559.49
# Tested order: (2, 2, 1), seasonal_order: (0, 2, 2, 12), AIC: 482.15
# Tested order: (2, 2, 1), seasonal_order: (1, 0, 0, 12), AIC: 571.88
# Tested order: (2, 2, 1), seasonal_order: (1, 0, 1, 12), AIC: 542.80
# Tested order: (2, 2, 1), seasonal_order: (1, 0, 2, 12), AIC: 513.83
# Tested order: (2, 2, 1), seasonal_order: (1, 1, 0, 12), AIC: 527.91
# Tested order: (2, 2, 1), seasonal_order: (1, 1, 1, 12), AIC: 507.74
# Tested order: (2, 2, 1), seasonal_order: (1, 1, 2, 12), AIC: 481.02
# Tested order: (2, 2, 1), seasonal_order: (1, 2, 0, 12), AIC: 601.70
# Tested order: (2, 2, 1), seasonal_order: (1, 2, 1, 12), AIC: 536.60
# Tested order: (2, 2, 1), seasonal_order: (1, 2, 2, 12), AIC: 497.70
# Tested order: (2, 2, 1), seasonal_order: (2, 0, 0, 12), AIC: 517.79
# Tested order: (2, 2, 1), seasonal_order: (2, 0, 1, 12), AIC: 515.10
# Tested order: (2, 2, 1), seasonal_order: (2, 0, 2, 12), AIC: 511.09
# Tested order: (2, 2, 1), seasonal_order: (2, 1, 0, 12), AIC: 494.31
# Tested order: (2, 2, 1), seasonal_order: (2, 1, 1, 12), AIC: 483.02
# Tested order: (2, 2, 1), seasonal_order: (2, 1, 2, 12), AIC: 483.02
# Tested order: (2, 2, 1), seasonal_order: (2, 2, 0, 12), AIC: 528.59
# Tested order: (2, 2, 1), seasonal_order: (2, 2, 1, 12), AIC: 500.35
# Tested order: (2, 2, 1), seasonal_order: (2, 2, 2, 12), AIC: 497.74
# Tested order: (2, 2, 2), seasonal_order: (0, 0, 0, 12), AIC: 657.37
# Tested order: (2, 2, 2), seasonal_order: (0, 0, 1, 12), AIC: 593.32
# Tested order: (2, 2, 2), seasonal_order: (0, 0, 2, 12), AIC: 545.78
# Tested order: (2, 2, 2), seasonal_order: (0, 1, 0, 12), AIC: 608.16
# Tested order: (2, 2, 2), seasonal_order: (0, 1, 1, 12), AIC: 475.23
# Tested order: (2, 2, 2), seasonal_order: (0, 1, 2, 12), AIC: 451.98
# Tested order: (2, 2, 2), seasonal_order: (0, 2, 0, 12), AIC: 739.15
# Tested order: (2, 2, 2), seasonal_order: (0, 2, 1, 12), AIC: 536.70
# Tested order: (2, 2, 2), seasonal_order: (0, 2, 2, 12), AIC: 462.60
# Tested order: (2, 2, 2), seasonal_order: (1, 0, 0, 12), AIC: 555.24
# Tested order: (2, 2, 2), seasonal_order: (1, 0, 1, 12), AIC: 509.20
# Tested order: (2, 2, 2), seasonal_order: (1, 0, 2, 12), AIC: 495.28
# Tested order: (2, 2, 2), seasonal_order: (1, 1, 0, 12), AIC: 505.61
# Tested order: (2, 2, 2), seasonal_order: (1, 1, 1, 12), AIC: 511.00
# Tested order: (2, 2, 2), seasonal_order: (1, 1, 2, 12), AIC: 461.97
# Tested order: (2, 2, 2), seasonal_order: (1, 2, 0, 12), AIC: 582.44
# Tested order: (2, 2, 2), seasonal_order: (1, 2, 1, 12), AIC: 508.08
# Tested order: (2, 2, 2), seasonal_order: (1, 2, 2, 12), AIC: 469.23
# Tested order: (2, 2, 2), seasonal_order: (2, 0, 0, 12), AIC: 504.60
# Tested order: (2, 2, 2), seasonal_order: (2, 0, 1, 12), AIC: 490.55
# Tested order: (2, 2, 2), seasonal_order: (2, 0, 2, 12), AIC: 493.14
# Tested order: (2, 2, 2), seasonal_order: (2, 1, 0, 12), AIC: 472.91
# Tested order: (2, 2, 2), seasonal_order: (2, 1, 1, 12), AIC: 489.25
# Tested order: (2, 2, 2), seasonal_order: (2, 1, 2, 12), AIC: 454.88
# Tested order: (2, 2, 2), seasonal_order: (2, 2, 0, 12), AIC: 511.60
# Tested order: (2, 2, 2), seasonal_order: (2, 2, 1, 12), AIC: 476.83
# Tested order: (2, 2, 2), seasonal_order: (2, 2, 2, 12), AIC: 480.53
#
# Best model found:
# Order: (1, 2, 2), Seasonal Order: (0, 1, 2, 12), AIC: 450.32
